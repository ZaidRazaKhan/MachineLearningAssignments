# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
data = pd.read_csv('./spambase/spambase.data')

# %%
def data_frame_to_numpy(data_frame, output_column):
    output = data_frame[output_column]
    data_frame = data_frame.drop(columns = output_column)
    return data_frame.to_numpy(), (output).to_numpy()

# %%
X, Y = data_frame_to_numpy(data, 'output')

# %%
class LogisticRegression:
    def __init__(self, lr=0.01, num_iter=100000, fit_intercept=True, verbose=False):
        self.lr = lr
        self.num_iter = num_iter
        self.fit_intercept = fit_intercept
        self.verbose = verbose
        
    def __add_intercept(self, X):
        intercept = np.ones((X.shape[0], 1))
        return np.concatenate((intercept, X), axis=1)
    
    def __sigmoid(self, z):
        return 1 / (1 + np.exp(-z))
    
    def __loss(self, h, y):
        return (-y * np.log(h) - (1 - y) * np.log(1 - h)).mean()
    
    def fit(self, X, y):
        if self.fit_intercept:
            X = self.__add_intercept(X)
        
        # weights initialization
        self.theta = np.zeros(X.shape[1])
        
        for i in range(self.num_iter):
            z = np.dot(X, self.theta)
            h = self.__sigmoid(z)
            gradient = np.dot(X.T, (h - y)) / y.size
            self.theta -= self.lr * gradient
            z = np.dot(X, self.theta)
            h = self.__sigmoid(z)
            loss = self.__loss(h, y)
            if(self.verbose ==True and i % 10000 == 0):
                print(f'loss: {loss} \t')
    
    def predict_prob(self, X):
        if self.fit_intercept:
            X = self.__add_intercept(X)
    
        return self.__sigmoid(np.dot(X, self.theta))
    
    def predict(self, X):
        return self.predict_prob(X).round()

# %%
model = LogisticRegression(lr=0.1, num_iter=300)

# %%
# %time model.fit(X, Y)
# Out:
# /home/zaidraza/workspace/MachineLearningAssignments/venv/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: divide by zero encountered in log
# /home/zaidraza/workspace/MachineLearningAssignments/venv/lib/python3.7/site-packages/ipykernel_launcher.py:19: RuntimeWarning: invalid value encountered in multiply
# /home/zaidraza/workspace/MachineLearningAssignments/venv/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in exp
# loss): nan
# loss: nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# loss): nan
# CPU times: user 747 ms, sys: 602 ms, total: 1.35 s
# Wall time: 395 ms

# %%
preds = model.predict(X)
(preds == Y).mean()
# Out:
# /home/zaidraza/workspace/MachineLearningAssignments/venv/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: overflow encountered in exp
# 0.6274722886329059

# %%
loss_history = model.cost_history()
loss_history[-1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-51-374159bc0605> in <module>
#       1 loss_history = model.cost_history()
# ----> 2 loss_history[-1]
#
# IndexError: list index out of range

# %%
model.theta
# Out:
# array([-7.68896901e+00, -3.44541705e-01, -2.69175194e+00, -9.16133119e-01,
#         4.50230905e-01, -3.16343781e-01,  1.13052435e-01,  7.01781394e-01,
#         2.87195245e-01,  1.34637880e-01, -8.49363588e-01,  1.30453980e-01,
#        -4.32216146e+00, -1.78041165e-01, -1.85342344e-01,  2.46718168e-01,
#         9.78454653e-01,  3.44466505e-01, -7.82589819e-02, -5.86562335e+00,
#         5.41926001e-01, -4.30754682e-01,  3.92000185e-01,  7.91127905e-01,
#         5.77993663e-01, -9.95385196e+00, -4.83528295e+00, -6.25843081e+00,
#        -2.25782172e+00, -1.79012300e+00, -1.88930245e+00, -1.22579298e+00,
#        -8.66348724e-01, -1.68720198e+00, -8.69819212e-01, -2.00081240e+00,
#        -1.47537348e+00, -2.21341594e+00, -1.79960995e-01, -1.45676168e+00,
#        -8.28507851e-01, -8.99065223e-01, -2.33779858e+00, -8.07417323e-01,
#        -1.42709368e+00, -3.96369674e+00, -3.28317379e+00, -8.36907697e-02,
#        -5.92731613e-01, -5.03283568e-01, -1.45067322e+00, -2.40091975e-01,
#         3.98483763e-01,  4.72467382e-01,  2.96980352e-03, -1.12265914e+01,
#         1.63738229e+01, -1.14050399e+00])
